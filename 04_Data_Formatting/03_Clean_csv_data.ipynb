# %% [markdown]
# ## Cleaning data from CSV file and inserting it it into IBC

# %% [markdown]
# #### Read Data from CSV

# %%
import pandas as pd
import numpy as np
from pycelonis import get_celonis
df = pd.read_csv('SalesJan2009.csv')
df.head(10)

# %% [markdown]
# #### Check if the datatypes of the columns are as expected

# %%
df.dtypes
# Out:
# Transaction_date     object
# Product              object
# Price                object
# Payment_Type         object
# Name                 object
# City                 object
# State                object
# Country              object
# Account_Created      object
# Last_Login           object
# Latitude            float64
# Longitude           float64
# dtype: object

# %% [markdown]
# #### Change the datatypes if required
# Changing Transaction_date to datetime Price to integer

# %%
df["Transaction_date"] = df["Transaction_date"].apply(pd.to_datetime)
df['Price'] = df.apply(lambda x: int(x['Price'].replace(',', '')),axis=1)

# %% [markdown]
# #### Drop uneeded columns
#
# droping Product Column

# %%
df.drop(["Product"], inplace=True, axis=1)
df.head()
# Out:
#      Transaction_date  Price Payment_Type               Name  \
# 0 2009-01-02 06:17:00   1200   Mastercard           carolina
# 1 2009-01-02 04:53:00   1200         Visa             Betina
# 2 2009-01-02 13:08:00   1200   Mastercard  Federica e Andrea
# 3 2009-01-03 14:44:00   1200         Visa              Gouya
# 4 2009-01-04 12:56:00   3600         Visa            Gerd W
#
#                            City     State         Country Account_Created  \
# 0                      Basildon   England  United Kingdom     1/2/09 6:00
# 1  Parkville                           MO   United States     1/2/09 4:42
# 2  Astoria                             OR   United States    1/1/09 16:21
# 3                        Echuca  Victoria       Australia   9/25/05 21:13
# 4  Cahaba Heights                      AL   United States  11/15/08 15:47
#
#      Last_Login   Latitude   Longitude
# 0   1/2/09 6:08  51.500000   -1.116667
# 1   1/2/09 7:49  39.195000  -94.681940
# 2  1/3/09 12:32  46.188060 -123.830000
# 3  1/3/09 14:22 -36.133333  144.750000
# 4  1/4/09 12:45  33.520560  -86.802500

# %% [markdown]
# #### Filling NaN values in Price column with the mean of the column

# %%
df['Price'] = df['Price'].fillna(df['Price'].mean())

# %% [markdown]
# #### Dropping all the columns with more than 90% Null values

# %%
df.dropna(thresh=int(df.shape[0] * .9), axis=1)
# Out:
#        Transaction_date  Price Payment_Type               Name  \
# 0   2009-01-02 06:17:00   1200   Mastercard           carolina
# 1   2009-01-02 04:53:00   1200         Visa             Betina
# 2   2009-01-02 13:08:00   1200   Mastercard  Federica e Andrea
# 3   2009-01-03 14:44:00   1200         Visa              Gouya
# 4   2009-01-04 12:56:00   3600         Visa            Gerd W
# ..                  ...    ...          ...                ...
# 993 2009-01-22 14:25:00   1200         Visa         Hans-Joerg
# 994 2009-01-28 05:36:00   3600         Visa         Christiane
# 995 2009-01-01 04:24:00   7500         Amex             Pamela
# 996 2009-01-08 11:55:00   1200       Diners              julie
# 997 2009-01-12 21:30:00   1200         Visa             Julia
#
#                              City             State         Country  \
# 0                        Basildon           England  United Kingdom
# 1    Parkville                                   MO   United States
# 2    Astoria                                     OR   United States
# 3                          Echuca          Victoria       Australia
# 4    Cahaba Heights                              AL   United States
# ..                            ...               ...             ...
# 993                       Belfast  Northern Ireland  United Kingdom
# 994                   Black River       Black River       Mauritius
# 995  Skaneateles                                 NY   United States
# 996                     Haverhill           England  United Kingdom
# 997  Madison                                     WI   United States
#
#     Account_Created    Last_Login   Latitude   Longitude
# 0       1/2/09 6:00   1/2/09 6:08  51.500000   -1.116667
# 1       1/2/09 4:42   1/2/09 7:49  39.195000  -94.681940
# 2      1/1/09 16:21  1/3/09 12:32  46.188060 -123.830000
# 3     9/25/05 21:13  1/3/09 14:22 -36.133333  144.750000
# 4    11/15/08 15:47  1/4/09 12:45  33.520560  -86.802500
# ..              ...           ...        ...         ...
# 993  11/10/08 12:15   3/1/09 3:37  54.583333   -5.933333
# 994     1/9/09 8:10   3/1/09 4:40 -20.360278   57.366111
# 995  12/28/08 17:28   3/1/09 7:21  42.946940  -76.429440
# 996  11/29/06 13:31   3/1/09 7:28  52.083333    0.433333
# 997  11/17/08 22:24  3/1/09 10:14  43.073060  -89.401110
#
# [998 rows x 11 columns]

# %% [markdown]
# #### Create a new categorical column saying premium if transaction price is greater than 5000 and Basic otherwise

# %%
df['Sale Category'] = np.where(df["Price"] > 5000, 'Premium', 'Basic')
df.head()
# Out:
#      Transaction_date   Product  Price Payment_Type               Name  \
# 0 2009-01-02 06:17:00  Product1   1200   Mastercard           carolina
# 1 2009-01-02 04:53:00  Product1   1200         Visa             Betina
# 2 2009-01-02 13:08:00  Product1   1200   Mastercard  Federica e Andrea
# 3 2009-01-03 14:44:00  Product1   1200         Visa              Gouya
# 4 2009-01-04 12:56:00  Product2   3600         Visa            Gerd W
#
#                            City     State         Country Account_Created  \
# 0                      Basildon   England  United Kingdom     1/2/09 6:00
# 1  Parkville                           MO   United States     1/2/09 4:42
# 2  Astoria                             OR   United States    1/1/09 16:21
# 3                        Echuca  Victoria       Australia   9/25/05 21:13
# 4  Cahaba Heights                      AL   United States  11/15/08 15:47
#
#      Last_Login   Latitude   Longitude Sale Category
# 0   1/2/09 6:08  51.500000   -1.116667         Basic
# 1   1/2/09 7:49  39.195000  -94.681940         Basic
# 2  1/3/09 12:32  46.188060 -123.830000         Basic
# 3  1/3/09 14:22 -36.133333  144.750000         Basic
# 4  1/4/09 12:45  33.520560  -86.802500         Basic

# %% [markdown]
# #### Push the data back into IBC in a data pool

# %%
data_pool = celonis.pools.find("enter your data pool id")
data_pool.push_table(df,"Name of Output Table in data pool", if_exists = 'replace')
